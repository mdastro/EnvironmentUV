# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../../Doutorado/GAMAII/Catalogue/Match08b_smallemlines_morphology.csv')

# %%
rsgs = data[data['UV_CLASS_YI2011']!='RSF']
rsgs = rsgs[rsgs['WHAN_CLASS']=='Retired/Passive']

# %%
np.unique(rsgs['ELLIPTICAL_CODE'].values)
# Out:
# array([ 0,  1, 10])

# %%
rsgs_morph = rsgs[rsgs['ELLIPTICAL_CODE']!=0]

# %%
rsgs_morph.iloc[:,-25:-1]
# Out:
#       MAG_ABSOLUTE_K UV_CLASS_YI2011  TYPE  BPT_CLASS       WHAN_CLASS  \
# 32        -20.246401         UV_WEAK     3  Composite  Retired/Passive
# 311       -19.227116         UV_WEAK     3        NaN  Retired/Passive
# 356       -19.827927       UV_UPTURN     3        NaN  Retired/Passive
# 380       -19.123315         UV_WEAK     3      LINER  Retired/Passive
# 563       -20.008419         UV_WEAK     3      LINER  Retired/Passive
# 568       -19.681240       UV_UPTURN     3  Composite  Retired/Passive
# 768       -21.072497       UV_UPTURN     3  Composite  Retired/Passive
# 784       -21.076242         UV_WEAK     3         SF  Retired/Passive
# 1017      -20.227861       UV_UPTURN     3        NaN  Retired/Passive
# 1045      -20.656113         UV_WEAK     3        NaN  Retired/Passive
# 1184      -19.564855         UV_WEAK     3      LINER  Retired/Passive
# 1353      -19.872178         UV_WEAK     3  Composite  Retired/Passive
# ...
